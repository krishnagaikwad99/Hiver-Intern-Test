# %% [markdown]
# # 02. Brand Selection Evidence Analysis
# Profiles candidate brands across conversation count, turn length, intent diversity ratio, canned response ratio, and overall quality score.

# %%
import sys
import os
sys.path.insert(0, '..')

import pandas as pd
from src.data.load import load_raw_dataset
from src.discovery.brands import analyze_all_brands

df = load_raw_dataset('../data/raw/twcs.csv')
brand_stats = analyze_all_brands(df)
brand_stats.head(10)
