# %% [markdown]
# # 03. Failure Analysis Notebook
# Analyzes the Top 5 real failure modes produced by the AI Support Agent during evaluation.

# %%
import json
import pandas as pd

with open('../reports/results/metrics.json', 'r') as f:
    metrics = json.load(f)

failures = metrics.get('top_5_failure_modes', [])
pd.DataFrame(failures)
